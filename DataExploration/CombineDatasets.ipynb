# %%
## combine datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#df_full_corr_wide = df_full_corr.pivot_table(index = ['subject','alcoholic'], columns='condition',values=df_full_corr_col[3:]).reset_index() df_full_corr_wide 

df1 = pd.read_csv('../Featuer_Folder/jason_derek_comb.csv')
## reading dataframe
df2 = pd.read_csv('./data/output_250_550ms/SubjectFeatureMeanAcrossIndividualChannels_S1obj.csv')
df3 = pd.read_csv('./data/output_250_550ms/SubjectFeatureMeanAcrossIndividualChannels_S2match.csv')
df4 = pd.read_csv('./data/output_250_550ms/SubjectFeatureMeanAcrossIndividualChannels_S2nomatch.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  X1      subject  alcoholic  CP5_F2_match  CP5_F2_nomatch  \
# 0           1   0  co2a0000364       True      0.200030        0.211414
# 1           2   1  co2a0000365       True      0.521817        0.272875
# 2           3   2  co2a0000368       True      0.281701        0.562318
# 3           4   3  co2a0000369       True      0.857280        0.706349
# 4           5   4  co2a0000370       True      0.719606        0.812764
#
#    CP5_F2_obj  CP2_FT8_match  CP2_FT8_nomatch  CP2_FT8_obj  ...  CZ_P8_obj  \
# 0    0.550771      -0.435512        -0.536246    -0.404910  ...   0.295287
# 1    0.457085      -0.626006        -0.469507    -0.584003  ...   0.147295
# 2    0.126599      -0.527075        -0.493691    -0.538776  ...  -0.217391
# 3    0.707260      -0.848527        -0.712812    -0.759786  ...  -0.160522
# 4   -0.049233      -0.472912        -0.489829    -0.607273  ...   0.343789
#
#    C3_P8_match  C3_P8_nomatch  C3_P8_obj  P300M_match  P300M_nomatch  \
# ...

# %%
print(sorted(df1['subject'].unique()))
# Out:
# ['co2a0000364', 'co2a0000365', 'co2a0000368', 'co2a0000369', 'co2a0000370', 'co2a0000371', 'co2a0000372', 'co2a0000375', 'co2a0000377', 'co2a0000378', 'co2a0000379', 'co2a0000380', 'co2a0000381', 'co2a0000382', 'co2a0000384', 'co2a0000385', 'co2a0000386', 'co2a0000387', 'co2a0000388', 'co2a0000390', 'co2a0000392', 'co2a0000394', 'co2a0000395', 'co2a0000396', 'co2a0000398', 'co2a0000400', 'co2a0000402', 'co2a0000403', 'co2a0000404', 'co2a0000405', 'co2a0000406', 'co2a0000407', 'co2a0000409', 'co2a0000410', 'co2a0000411', 'co2a0000412', 'co2a0000414', 'co2a0000415', 'co2a0000416', 'co2a0000417', 'co2a0000418', 'co2a0000419', 'co2a0000421', 'co2a0000422', 'co2a0000423', 'co2a0000424', 'co2a0000425', 'co2a0000426', 'co2a0000427', 'co2a0000428', 'co2a0000429', 'co2a0000430', 'co2a0000432', 'co2a0000433', 'co2a0000434', 'co2a0000435', 'co2a0000436', 'co2a0000437', 'co2a0000438', 'co2a0000439', 'co2a0000440', 'co2a0000443', 'co2a0000444', 'co2a0000445', 'co2a0000447', 'co2c0000337', 'co2c00
# ...

# %%
print(sorted(df2['subject'].unique()))
# Out:
# ['co2a0000364', 'co2a0000365', 'co2a0000368', 'co2a0000369', 'co2a0000370', 'co2a0000371', 'co2a0000372', 'co2a0000375', 'co2a0000377', 'co2a0000378', 'co2a0000379', 'co2a0000380', 'co2a0000381', 'co2a0000382', 'co2a0000384', 'co2a0000385', 'co2a0000386', 'co2a0000387', 'co2a0000388', 'co2a0000390', 'co2a0000392', 'co2a0000394', 'co2a0000395', 'co2a0000396', 'co2a0000398', 'co2a0000400', 'co2a0000402', 'co2a0000403', 'co2a0000404', 'co2a0000405', 'co2a0000406', 'co2a0000407', 'co2a0000409', 'co2a0000410', 'co2a0000411', 'co2a0000412', 'co2a0000414', 'co2a0000415', 'co2a0000416', 'co2a0000417', 'co2a0000418', 'co2a0000419', 'co2a0000421', 'co2a0000422', 'co2a0000423', 'co2a0000424', 'co2a0000425', 'co2a0000426', 'co2a0000427', 'co2a0000428', 'co2a0000429', 'co2a0000430', 'co2a0000432', 'co2a0000433', 'co2a0000434', 'co2a0000435', 'co2a0000436', 'co2a0000437', 'co2a0000438', 'co2a0000439', 'co2a0000440', 'co2a0000443', 'co2a0000444', 'co2a0000445', 'co2a0000447', 'co2c0000337', 'co2c00
# ...
